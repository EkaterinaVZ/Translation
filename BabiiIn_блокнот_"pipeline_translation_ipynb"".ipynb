# %% [markdown]
# <a href="https://colab.research.google.com/github/EkaterinaVZ/Translation/blob/main/BabiiIn_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82_%22pipeline_translation_ipynb%22%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Пример использования библиотеки Hugging Face для автоматического перевода

# %% [markdown]
# Устанавливает библиотеку Hugging Face (модуль transformers)

# %%
# !pip install transformers sentencepiece
# Out:
# ...
#      |████████████████████████████████| 3.1 MB 4.2 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 38.6 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 36.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 51.6 MB/s
# ...
#      |████████████████████████████████| 61 kB 518 kB/s
# ...
#      |████████████████████████████████| 895 kB 40.5 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %% [markdown]
# Создаем пайплайн для создания автоматического перевода

# %%
from transformers import pipeline

translator = pipeline("translation_en_to_ru", "Helsinki-NLP/opus-mt-en-ru")
# Out:
# Downloading:   0%|          | 0.00/1.11k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/293M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/784k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.03M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.48M [00:00<?, ?B/s]

# %% [markdown]
# Используем пайплайн для создания перевода

# %%
translator("Get team access controls and discussions for your contributors in an organization")
# Out:
# [{'translation_text': 'Найдите механизмы контроля доступа и обсуждения для своих вкладчиков в организации'}]
